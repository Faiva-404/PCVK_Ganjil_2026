# %% [markdown]
# <a href="https://colab.research.google.com/github/Faiva-404/PCVK_Ganjil_2026/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pylab as plt

# Menggunakan gambar gedung (variabel 'image' yang berhasil dimuat)
img_base = cv.cvtColor(image, cv.COLOR_BGR2RGB)
h, w, c = img_base.shape

# Tugas 2: Garis Vertikal & Garis Menyilang Diagonal
img_task2 = img_base.copy()
# Garis Vertikal di tengah
for x in range(h):
  img_task2[x, int(w / 2)] = [255, 255, 255]

# Garis Diagonal Menyilang (X)
for i in range(min(h, w)):
  img_task2[i, i] = [255, 255, 255]  # Kiri atas ke kanan bawah
  img_task2[i, w - 1 - i] = [255, 255, 255]  # Kanan atas ke kiri bawah

# Tugas 3: Garis Horizontal Putih di Tengah dengan Panjang Terbatas (150 piksel)
img_task3 = img_base.copy()
panjang_garis = 150
start_x = int(w / 2) - int(panjang_garis / 2)
end_x = int(w / 2) + int(panjang_garis / 2)

for y in range(start_x, end_x):
  img_task3[int(h / 2), y] = [255, 255, 255]

# Tugas 4: Kotak Warna Putih di Sembarang Tempat
img_task4 = img_base.copy()
img_task4[30:100, 50:150] = [255, 255, 255]  # Area baris 30-100, kolom 50-150

# Menampilkan Hasil Seluruh Tugas D2
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(img_task2)
axes[0].set_title("2. Vertikal & Diagonal Silang")
axes[0].axis("off")

axes[1].imshow(img_task3)
axes[1].set_title("3. Horizontal Pendek")
axes[1].axis("off")

axes[2].imshow(img_task4)
axes[2].set_title("4. Kotak Putih Sembarang")
axes[2].axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2748/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...
